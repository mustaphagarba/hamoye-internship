# %% [markdown]
# <a href="https://colab.research.google.com/github/mustaphagarba/hamoye-internship/blob/main/Hamoye_Intro_to_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A notebook detailing my exploration of the provided electric utilities dataset forthe Hamoye DS Internship

# %%
import pandas as pd
import numpy as np

# %%
source_url = "https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv"
data = pd.read_csv(source_url)
data.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's look at summary data for this dataset, then for missing values and other errata.

# %%
data.describe()
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count      29523.000000  ...         29523.000000
# mean         118.601836  ...            19.304354
# std           74.178353  ...          2091.540939
# min            1.000000  ...           -41.501000
# 25%           55.000000  ...             1.940000
# 50%          122.000000  ...             4.127000
# 75%          176.000000  ...             7.745000
# max          514.000000  ...        359278.000000
#
# [8 rows x 7 columns]

# %%
data.isnull()
# Out:
#        record_id  ...  fuel_cost_per_mmbtu
# 0          False  ...                False
# 1          False  ...                False
# 2          False  ...                False
# 3          False  ...                False
# 4          False  ...                False
# ...          ...  ...                  ...
# 29518      False  ...                False
# 29519      False  ...                False
# 29520      False  ...                False
# 29521      False  ...                False
# 29522      False  ...                False
#
# [29523 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
# looking at the rows where the fuel_unit is missing

null_fuel = data[data.isnull().any(axis=1)]
null_fuel.head(25)
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 66      f1_fuel_1994_12_9_3_13  ...                7.480
# 152     f1_fuel_1994_12_8_1_14  ...                0.485
# 277     f1_fuel_1994_12_74_0_3  ...                0.440
# 626    f1_fuel_1994_12_117_0_1  ...                0.615
# 627    f1_fuel_1994_12_117_0_4  ...                0.480
# 829    f1_fuel_1994_12_189_0_1  ...                2.380
# 830    f1_fuel_1994_12_189_0_4  ...                2.410
# 832    f1_fuel_1994_12_189_0_7  ...                1.810
# 834   f1_fuel_1994_12_189_0_13  ...                2.070
# 835    f1_fuel_1994_12_189_1_1  ...                2.060
# 836    f1_fuel_1994_12_189_1_4  ...                2.170
# 933    f1_fuel_1994_12_144_0_1  ...                1.090
# 934    f1_fuel_1994_12_144_0_4  ...                1.370
# 935    f1_fuel_1994_12_144_0_7  ...                1.350
# 936   f1_fuel_1994_12_144_0_10  ...                1.280
# ...

# %%
null
